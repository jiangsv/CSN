# %%
import csv, os, random
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile
from docx import Document
from docx.shared import Inches
from datetime import datetime

t = datetime.now()        
    
def fetch_dataFrame(file_name, n):
    ## read data from excel
    os.chdir(r"/Users/yunjiang/OneDrive/365 Documents")
    df = pd.read_excel(f'{file_name} exam.xlsx', index_col=0).fillna('无')
    lst = []
    while len(lst) <= n-1 :
        i = random.choice(range(1,(len(df.index))))
        if i not in lst:
            lst.append(i)
        else:
            continue
    random_df = pd.DataFrame(df, index = lst).reset_index()
    return random_df

    

def gen_select_answer_data(random_df):
    ## read answer from data
    random_answer = random_df['answer']
    answer_lst = []
    for i in range(len(random_answer)):
        if i%10 == 0 :
            answer_index = f'{i+1}-{i//10*10+10}'
            answer_lst.append(answer_index)
        answer_lst.append(random_answer[i])
    return answer_lst
    
def gen_write_answer_data(random_df):
    ## read answer from data
    random_answer = random_df['answer']
    answer_lst = []
    for i in range(len(random_answer)):
        answer_lst.append(f'#{i+1}')
        answer_lst.append(random_answer[i])
    return '\n'.join(answer_lst) 


def gen_selcet_question(random_df, n):
    ## modify lines 
    line= ''
    for i in range(n):
        line = line + str(i + 1) + '：' + str(random_df.loc[i][1]) + '\n'
        count = 0
        for n in (2, 3, 4, 5):
            count = count + len(str(random_df.loc[i][n])) + 4
            if count<=55:
    ## choiceslen跟字体大小调节 小5号字体为60
                line = line + chr(95 + n).upper() + '.' + str(random_df.loc[i][n]) + '   '
            else:
                count = len(str(random_df.loc[i][n]))
                line = line +'\n' + chr(95 + n).upper() + '.' + str(random_df.loc[i][n]) + '   '
        line = line + '\n'
    return line
       

def gen_write_question(random_df,n):
    line= ''
    for i in range(n):
        choiceslen = int(0)
        line = line +  str(i + 1) + '.' + random_df.loc[i][1]
        line = line + '\n'
    return line
        
    
def gen_fleet_questions(fleet, select=20, qrh=2, write=4):
    select_file = f'{fleet} select'
    write_file = f'{fleet} write'
    qrh_file = f'{fleet} qrh'
    
    select_df = fetch_dataFrame(select_file, select)
    select_block = gen_selcet_question(select_df, select)

    qrh_df = fetch_dataFrame(qrh_file, write)
    qrh_block = gen_write_question(qrh_df, write)
    
    write_df = fetch_dataFrame(write_file, write)
    write_block = gen_write_question(write_df, write)
   
    select_answer = gen_select_answer_data(select_df)
    write_answer = gen_write_answer_data(write_df)
    
   
    paragraph = f'''{fleet}   姓名_____________    员工号________    申请等级___    面试结果____ 成绩______
选择题 每题2分（在左侧题号处写处答案)
{select_block}
熟记项目 不记分，必须全对 (可写在背面)
{qrh_block}
简答题 每题5分 (可写在背面)
{write_block}

------
{select_answer}
{write_answer}
'''
    
    return paragraph
    
def pub( *fleets):
    for fleet in fleets:
        document = Document()
        p = document.add_paragraph(gen_fleet_questions(fleet))
        document.save(f'{fleet} 卷子.docx')

# %%
print(gen_fleet_questions('B777'))
# Out:
# B777   姓名_____________    员工号________    申请等级___    面试结果____ 成绩______
# 选择题 每题2分（在左侧题号处写处答案)
# 1：在哪种情况下ILS可以重新调谐？
# A.按压TO/GA电门   B.脱开自动驾驶和断开两部飞行指引仪电门
# C.1500英尺无线电高度以上 MCP进近方式解除选择   D.以上都可以
# 2：右边的EFIS控制面板能控制中央下部的MFD吗？
# A.可以   B.不行   C.在特定条件下才可以   D.无
# 3：当加法器与计算器相差多少公斤燃油在一定时间会在CDU草稿行出现FUEL DISAGREE信息？
# A.2500公斤   B.3200公斤   C.4100公斤   D.4500公斤
# 4：当襟翼5为爬升减推力点时，在起飞前使用襟翼5起飞起飞基准页面“TAKEOFF REF”行输入5时CDU草稿行会显示什么信息？
# A.无效输入   B.检查性能   C.没有信息   D.无
# 5：当ADIRU没有对准时，V2将显示什么？
# A.不显示任何内容   B.显示虚线   C.显示位置是空白   D.无
# 6：当选择等待页面后在或低于14000英尺时页面的航段时间为多少？
# A.1分钟   B.1.5分钟   C.2分钟   D.2.5分钟
# 7：当ADIRU故障后对FLCH的述说对吗？
# A.可以使用FLCH，但是不稳定   B.可以使用FLCH，工作可靠   C.不可以使用FLCH
# D.无
# 8：如果发送到ND的资料量超过显示的容量会显示什么信息？
# A.显示EXCESS DATA信息   B.显示EXCESS FULL信息   C.显示DATA FULL信息
# D.无
# 9：左中右三部VHF哪部仅用于声音通讯
# A.左VHF   B.中VHF   C.右VHF   D.中和右VHF
# 10：有关备用俯仰配平手柄使用的说法哪个正确？
# A.备用俯仰配平的两个手柄分别控制左安定面和右安定面配平
# B.单独使用一个手柄时安定面配平速率只有同时使用两个手柄时的一半   C.必须同时使用两个手柄才能对安定面进行配平
# D.向后拉两个手柄时安定面的移动产生低头力矩
# 11：单发时TAC工作配平回中电门可以控制方向舵配平吗？
# A.可以   B.不行   C.不受影响   D.无
# 12：在什么情况下着陆检查单的襟翼项目没有闭环路探测？
# A.单发时   B.中央液压系统失效时   C.使用备用方式放襟翼   D.无
# 13：在OFFPATH DES页面的“TO DRAG”是什么含义？
# A.至阻力下降圈的距离   B.到要求拉减速板时机的距离   C.要求减速   D.无
# 14：关键性警告在姿态显示和航向/航迹罗盘之间以什么形式显示？
# A.以红色大写字母显示   B.以大的缩写字母显示   C.以琥珀色的大写字母显示   D.无
# 15：主起落架不一致落地滑梯能在机头抬起时使用吗？
# A.能都可以使用   B.不能只能在中后部撤离   C.不需要考虑这一点   D.无
# 16：起飞后什么时候在速度带上的V1和VR消失？
# A.离地时   B.选择了VREF    C.收轮时   D.无
# 17：水平导航在起飞前预位什么时候自动接通？
# A.现用航路在2.5海里之内在或高于50英尺时   B.现用航路在2海里之内在或高于80英尺时
# C.现用航路在1.5海里之内在或高于100英尺时   D.无
# 18：侧滑指示在完全位移坡度角35°或大于35°：
# A.框变为实心白色   B.框变为黄色   C.框变为实心黄色   D.无
# 19：在什么高度襟翼机动速度才能显示？
# A.大约10000英尺以下   B.大约15000英尺以下   C.大约20000英尺以下
# D.大约25000英尺以下
# 20：着陆高度指示起飞跑道或机场的着陆高度它们以下面那种条件来划分？
# A.以大的大写字母显示   B.指示起飞跑道或机场的着陆高度是以150海里或到下降点前以先到为准
# C.指示起飞跑道或机场的着陆高度是以500海里或到目的地的一半距离以先到为准
# D.指示起飞跑道或机场的着陆高度是以300海里或到目的地的一半距离以先到为准
#
# 熟记项目 不记分，必须全对 (可写在背面)
# 1.空速不可靠
# 2.左、右发动机火警
# 3.左、右发动机自动起动
# 4.双发失效/失速
#
# 简答题 每题5分 (可写在背面)
# 1.做自动着陆时，FLARE（拉平）方式在多少英尺时预位，多少英尺时接通？
# 2.在什么情况下，主油箱不满时中央油箱可以加到油，最多可加多少？
# 3.B777-300ER飞机的主轮距、前主轮距分别是多少？
# 4.B777机型何时使用改善爬升性能起飞？有什么好处？
#
#
# ------
# ['1-10', 'D', 'C', 'C', 'A', 'B', 'A', 'A', 'A', 'A', 'C', '11-20', 'B', 'C', 'A', 'A', 'A', 'A', 'A', 'C', 'C', 'A']
# #1
# 1500英尺。40-60英尺
# #2
# 只要中央油箱油量加上实际无燃油重量不超过最大无燃油重量，并
# 遵守了重心限制，则主油箱不满时中央油箱也可加到 1360 公斤以
# 内。
# #3
# 31.22;10.97
# #4
# 改善爬升性能起飞
# 当跑道长度不是限制因素时，可以使用更多的跑道来使飞机加速到更大的起飞和爬升速度，从而增加爬升限制重量。这可以改善爬升梯度，从而增加爬升和越障限制重量。V1、VR 和 V2 都要增大，而且必需从签派或机场分析中获得。

# %%
from datetime import datetime
t = datetime.now() 
stamp = f'Issue Date: {t.strftime("%Y-%m-%d")}'

# %%
stamp
# Out:
# 'Issue Date: 2020-02-11'
