# %%
import csv, os, random
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile


def gen_dataframe(fleet):
    os.chdir(r"/Users/yunjiang/OneDrive/365 Documents") 
    df = pd.read_excel(f'{fleet} exam.xlsx', index_col=0)
# 读取excel中的题目
    _lst = []
    while len(_lst) <= 24:
        i = random.choice(range(1,(len(df.index))))
        if i not in _lst:
            _lst.append(i)
        else:
             continue
# 建立随机题库容器

    qa_df = pd.DataFrame(df, index = _lst).reset_index().replace(self, to_replace=None, value='')
    
    a_s = qa_df['answer']

    line= ''
    for i in range(25):
        choiceslen = int(0)
        line = line + str(i + 1) + '：' + str(qa_df.loc[i][1]) + '\r\n'
        for n in (2, 3, 4, 5):
            choiceslen = choiceslen + len(str(qa_df.loc[i][n])) + 4 * (n - 2)
            if choiceslen<=60:
# choiceslen跟字体大小调节 小5号字体为60
                line = line + chr(95 + n).upper() + '.' + str(qa_df.loc[i][n]) + '    '
            else:
                line = line + '\r\n' + chr(95 + n).upper() + '.' + str(qa_df.loc[i][n]) + '    '
                choiceslen = int(0)
        line = line + '\r\n'
    print(line)

# %%
import csv, os, random
import pandas as pd
import numpy as np
from pandas import ExcelWriter
from pandas import ExcelFile

os.chdir(r"/Users/yunjiang/OneDrive/365 Documents") 
df = pd.read_excel(f'A330 exam.xlsx', index_col=0)
# 读取excel中的题目
_lst = []
while len(_lst) <= 24:
    i = random.choice(range(1,(len(df.index))))
    if i not in _lst:
        _lst.append(i)
    else:
        continue
        
df.fillna('无')
# Out:
#                                           题目                         选项1  \
# 机型
# 1               在地面，发动机关断，在较热的情况下电子仪表舱如何调节温度  空气由地面冷却活门吸入电子仪表舱，经通风抽气活门排出
# 2    在你的预先检查中，你设置ADIRS开始校准，这时ON BAT灯亮，为什么会这样               这是提醒校准正使用电瓶电源
# 3               在过站期间，你注意到两个ND上有剩余地速，你应该如何修正       发动机关车，有必要执行ADIRS的完全校准
# 4                  你放出了客舱面罩。一旦启动，能持续的有效时间是多长                     10到12分钟
# 5                         N/100%供气选择电门的作用是什么        100%位提供最大压力，N位提供正常压力
# ..                                       ...                         ...
# 346                                RVSM空域范围：             FL290-FL410（含）
# 347                        RVSM空域范围飞机之间的垂直间隔                     1000ft
# 348                        ADR2失效能进行RVSM飞行吗？                         不能
# 349                         FCU2失效能进行RVSM飞行吗                          能
# 350                         FWC2失效能进行RVSM飞行吗                          能
#
#                                 选项2                             选项3  \
# 机型
# 1    来自APU的引气经过电子仪表舱然后自上而下经地面冷却活门排出  地面冷却系统通过一个风扇从电子仪表舱抽气经过地面冷却活门排出
# 2                      这显示几秒钟测试电瓶电路                    这是提醒你接通飞机的电瓶
# 3    基于ND1和2的指示，有必要对ADIRS1和2 进行快速校准               在飞机关断之前没有可实施的修正动作
# 4                           33到35分钟                         15到22分钟
# 5            N位提供空气/氧气混和气，100%位提供纯氧          N位切断氧气供应，100%位确保正常氧气供应
# ..                              ...                             ...
# 346                    FL280-FL390                  在RVSM区域内所有高度层.
# 347                         2000ft                          1000M.
# 348                             能.                                无
# 349                            不能.                                无
# 350                            不能.                                无
#
#                                              选项4  类型 answer
# 机型
# 1    在发动机关断的情况下没有额外的冷却可用，一个外部的冷却组件必须经过地面冷却活门进行连接  单选      C
# 2                                    这指示电瓶电路存在故障  单选      B
# 3                             通过将三部惯导瞬间关断来执行快速校准  单选      D
# 4                                           60分钟  单选      C
# 5                  N/100%选择电门用于在飞行前检查期间检查氧气面罩的供氧  单选      B
# ..                                           ...  ..    ...
# 346                                            无  单选      A
# 347                                            无  单选      A
# 348                                            无  单选      A
# 349                                            无  单选      A
# 350                                            无  单选      A
#
# [350 rows x 7 columns]

# %%
qa_df
# Out:
#     index                                                 题目  \
# 0     286                    开车后APU引气关断是为了防止发动机排出的废气进入空调系统吗？
# 1     124                                      下列哪种情况预计开车不成功
# 2     213                         起飞离地后飞机高度距地面（ ）英尺可以使用自动驾驶仪
# 3     181  如果某一个主起落架上有两个轮胎放气(另一个主起落架没有轮胎放气),则滑行应限速( )海里且前...
# 4      81                在空中起落架收起后，把防滞和前轮转弯开关关断在接通，自动刹车在预位方式
# 5     281                           飞行操纵检查必须使用ECAM 飞行操纵页面进行。
# 6      95                                  中断起飞过程中哪一项不是副驾驶职责
# 7     105                  在结冰条件下放出缝翼时避免长时间飞行，最小速度不得低于（全形态下）
# 8     346                                          RVSM空域范围：
# 9     296  氧气面罩测试中,在面罩收存箱第一次按箭头方向按下并保持复位/测试按钮,观察闪烁灯短时变成( ...
# 10    215                                          使用干重（DOW）
# 11    189                                       检查滑油时,最小滑油量为
# 12    192                          在地面发动机开车后如果输入飞机重量/无燃油重心应在
# 13     17                                   自动驾驶接通，哪一句陈述是正确的
# 14      9                                    增压系统的安全活门的作用是什么
# 15    179                                  停留刹车刹上时双发EPR值不得大于
# 16    275                                   在速度为（ ）KT是建议收回反推
# 17     33                          你将自动刹车设置在中位着陆，着陆后什么触发自动刹车
# 18    232                                 FCOM计算飞行计划的巡航高度层表是
# 19    166               在FMA上显示CAT1的ILS进近时使用自动驾驶的最低高度是( )英尺?
# 20    147                                           能否适用单发滑行
# 21    292          发动机起动前应检查发动机滑油量在或大于( )+预计消耗量[预计最大平均消耗量约等于
# 22    104  在正常巡航范围内，直线飞行中自动驾驶仪接通，发动机推力对称，以及机翼油箱燃油对称时，方向舵配...
# 23    335                           实行客舱不增压飞行的性能数据怎么修正ISA偏差？
# 24    219                                              起飞重量：
#
#                                                   选项1  \
# 0                                                  是
# 1                                   高温或高高度机场而使引气性能下降。
# 2                                                  30
# 3                                                7和30
# 4                                                  是
# 5                                                   对
# 6                                             监视刹车反应
# 7                                                VLS
# 8                                     FL290-FL410（含）
# 9                                                黄 黑
# 10  飞机结构、动力装置、装备、系统和其它被视作为飞机整体的一个部分的各个项目的重量。该重量基本上...
# 11                                              10夸脱
# 12                                             起始B页面
# 13                           减速板被隔离，速度控制由自动推力和管理速度来控制
# 14                                    防止在人工方式座舱垂直速度过大
# 15                                               1.32
# 16                                              50KT
# 17                                   主起落架一压缩就触发自动刹车系统
# 18                                        以CG 37%计算的
# 19                                           160英尺AGL
# 20                                                 能
# 21                                     12夸脱 0.3夸脱/小时
# 22                                        0．9右，0.6左之间
# 23                    ISA 1度 修正0.01kg/海里或0.022 lb/海里
# 24                                       无燃油重量+起飞燃油量
#
#                                                   选项2  \
# 0                                                 不是
# 1                                在高温或高高度机场发动机EGT 裕度变小
# 2                                                  50
# 3                                                3和30
# 4                                                 不是
# 5                                                  不对
# 6                                            把反推拉到最大
# 7                                              VLS+5
# 8                                        FL280-FL390
# 9                                                 黄 绿
# 10  制造空重加上用户项目的重量，包括飞行和乘务机组人员及其行李、不可用燃油、发动机滑动、紧急设备...
# 11                                              11夸脱
# 12                                            燃油预测页面
# 13                              减速板不受自动驾驶影响，整个范围内功能正常
# 14                                         防止在水上迫降时进水
# 15                                               1.19
# 16                                               60KT
# 17                                       当扰流板放出触发自动刹车
# 18                                        以CG 33%计算的
# 19                                              离地5秒内
# 20                                                不能
# 21                                     12夸脱 0.7夸脱/小时
# 22                                        1．9右及1.6左之间
# 23                   ISA 10度 修正0.01kg/海里或0.022 lb/海里
# 24                                          OEW+起飞燃油
#
#                                                   选项3  \
# 0                                                 NaN
# 1                                       外部气源组的性能勉强够用
# 2                                                 100
# 3                                               3和72
# 4
# 5                                                 NaN
# 6                                              报告ATC
# 7                                             VLS+10
# 8                                     在RVSM区域内所有高度层.
# 9                                                黄 蓝
# 10  去除所有可用燃油和飞机载荷之后的某种特定操作型号的飞机总重。使用空重加上某种特定项目即餐饮、...
# 11                                              12夸脱
# 12                                              无法输入
# 13                                减速板手柄受限，仅能移动至1/2的位置
# 14                                           防止座舱高度过大
# 15                                               1.24
# 16                                              70KT
# 17                                        当反喷开锁触发自动刹车
# 18                                            符合所有CG
# 19                                          400英尺AGL
# 20                                                NaN
# 21                                     11夸脱 0.3夸脱/小时
# 22                                        1.0右及1.0左之间
# 23                         ISA 1度 修正1 kg/海里或2.2 lb/海里
# 24                                      OEW+起飞燃油+商载.
#
#                           选项4  类型 answer
# 0                         NaN  单选      A
# 1                     以上全都正确   单选      D
# 2                         150  单选      C
# 3                         NaN  单选      B
# 4                              单选      B
# 5                         NaN  单选      A
# 6                              单选      B
# 7                     VLS+15   单选      C
# 8                         NaN  单选      A
# 9                         NaN  单选      A
# 10                        NaN  单选      C
# 11                      13夸脱   单选      C
# 12                        NaN  单选      B
# 13  减速板的最大偏转大约是一半，即便将手柄移至全放出位  单选      B
# 14                防止在座舱中过大的压差  单选      D
# 15                        NaN  单选      C
# 16                       80KT  单选      C
# 17              一旦前轮压缩就触发自动刹车  单选      B
# 18                        NaN  单选      A
# 19                        NaN  单选      B
# 20                        NaN  单选      A
# 21                        NaN  单选      B
# 22                        NaN  单选      B
# 23                      无须修正   单选      A
# 24                        NaN  单选      A

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-f7b3598f5575> in <module>
# ----> 1 DF1 = data.frame(C1= c(1, 5, 14, NA, 54), C2= c(9, NA, NA, 3, 42), C3= c(9, 7, 42, 87, NA))
#       2 DF1
#
# NameError: name 'data' is not defined

# %%
a = 'sdfsf'
b = 'sfd'
def asdf():
    print(a)
    print(b)
asdf()
# Out:
# sdfsf
# sfd

# %%
a.append("d")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-7304c86f6560> in <module>
# ----> 1 a.append("d")
#
# AttributeError: 'str' object has no attribute 'append'
